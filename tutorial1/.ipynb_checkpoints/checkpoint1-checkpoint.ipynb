# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for compeletion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>.
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pd.read_csv("../data/states_edu.csv")
df.head(10)
# Out:
#                  PRIMARY_KEY                 STATE  YEAR  ENROLL  \
# 0               1992_ALABAMA               ALABAMA  1992     NaN
# 1                1992_ALASKA                ALASKA  1992     NaN
# 2               1992_ARIZONA               ARIZONA  1992     NaN
# 3              1992_ARKANSAS              ARKANSAS  1992     NaN
# 4            1992_CALIFORNIA            CALIFORNIA  1992     NaN
# 5              1992_COLORADO              COLORADO  1992     NaN
# 6           1992_CONNECTICUT           CONNECTICUT  1992     NaN
# 7              1992_DELAWARE              DELAWARE  1992     NaN
# 8  1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992     NaN
# 9               1992_FLORIDA               FLORIDA  1992     NaN
#
#    TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  \
# 0      2678885.0         304177.0      1659028.0       715680.0
# 1      1049591.0         106780.0       720711.0       222100.0
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
# Take out rows with missing avg math 8 score
df.dropna(subset=['AVG_MATH_8_SCORE'], inplace=True)

# More changes made for feature engineering portion

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen Outcome Variable for Test: *AVG_MATH_8_SCORE*

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
print(df["YEAR"].nunique())
# 33 years in total, but 13 years that have values for AVG_MATH_8_SCORE
# Out:
# 13

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average outcome score across all years?

# %%
states = df.groupby("STATE")
print("MICHIGAN AVG MATH 8 SCORE:", states.get_group("MICHIGAN")["AVG_MATH_8_SCORE"].mean())
print("OHIO AVG MATH 8 SCORE:", states.get_group("OHIO")["AVG_MATH_8_SCORE"].mean())
# Michigan: 276.166667, Ohio: 282.250000
# Ohio has the higher average outcome score across all years
# Out:
# MICHIGAN AVG MATH 8 SCORE: 276.1666666666667
# OHIO AVG MATH 8 SCORE: 282.25

# %% [markdown]
# Find the average for your outcome score across all states in 2019

# %%
years = df.groupby("YEAR")
print("2019 AVERAGE MATH 8 SCORE:", years.get_group(2019)["AVG_MATH_8_SCORE"].mean())
# Out:
# 2019 AVERAGE MATH 8 SCORE: 281.2641509433962

# %% [markdown]
# Find the maximum outcome score for every state.
#
# Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %%
states["AVG_MATH_8_SCORE"].max()
# Out:
# STATE
# ALABAMA                 269.0
# ALASKA                  283.0
# ARIZONA                 283.0
# ARKANSAS                279.0
# CALIFORNIA              277.0
# COLORADO                292.0
# CONNECTICUT             289.0
# DELAWARE                284.0
# DISTRICT_OF_COLUMBIA    269.0
# DODEA                   293.0
# FLORIDA                 281.0
# GEORGIA                 281.0
# HAWAII                  281.0
# IDAHO                   287.0
# ILLINOIS                285.0
# INDIANA                 288.0
# IOWA                    286.0
# KANSAS                  290.0
# KENTUCKY                282.0
# LOUISIANA               273.0
# MAINE                   289.0
# MARYLAND                288.0
# MASSACHUSETTS           301.0
# MICHIGAN                280.0
# MINNESOTA               295.0
# MISSISSIPPI             274.0
# MISSOURI                286.0
# MONTANA                 293.0
# NATIONAL                285.0
# NEBRASKA                288.0
# NEVADA                  278.0
# ...

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
# Instructional expenditure per student. How much money was allocated towards student-teacher interactions.
# Did kids with more/better teacher interaction do better on the tests?
df.dropna(subset=['INSTRUCTION_EXPENDITURE'], inplace=True)
df.dropna(subset=['ENROLL'], inplace=True)
df["INSTRUCTION_PER_STUDENT"] = df["INSTRUCTION_EXPENDITURE"] / df["ENROLL"]
df
# Out:
#              PRIMARY_KEY          STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 408         2000_ALABAMA        ALABAMA  2000   730184.0      4885917.0
# 410         2000_ARIZONA        ARIZONA  2000   814807.0      5479168.0
# 411        2000_ARKANSAS       ARKANSAS  2000   450751.0      2844855.0
# 412      2000_CALIFORNIA     CALIFORNIA  2000  5941946.0     46628207.0
# 414     2000_CONNECTICUT    CONNECTICUT  2000   530363.0      5884078.0
# ...                  ...            ...   ...        ...            ...
# 1219       2015_VIRGINIA       VIRGINIA  2015  1279867.0     15857524.0
# 1220     2015_WASHINGTON     WASHINGTON  2015  1072359.0     13709442.0
# 1221  2015_WEST_VIRGINIA  WEST_VIRGINIA  2015   279565.0      3478401.0
# 1222      2015_WISCONSIN      WISCONSIN  2015   861813.0     11637376.0
# 1223        2015_WYOMING        WYOMING  2015    93867.0      1962874.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %% [markdown]
# Feature engineering justification: **I chose to make a variable measuring the intructional expenditure per student enrolled in the state to assess whether there is a coorelation between resources allocated to teacher-on-student interaction and 8th grade student's ability to perform well on the NAEP Math Exam.**

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
df.plot.scatter(x='INSTRUCTION_EXPENDITURE', y='AVG_MATH_8_SCORE', alpha=0.5)
plt.xlabel('Instruction Expenditure')
plt.ylabel('8th Grade Math Score')
# Out:
# Text(0, 0.5, '8th Grade Math Score')

# %% [markdown]
# **This is a scatterplot comparing intruction expenditure and 8th graders' performance on the NAEP Math Exam. There seems to be little to no coorelation between the two variables; as instruction expenditure increases, the scores stay more or less the same.**

# %% [markdown]
# **Visualization 2**

# %%
df.plot.scatter(x='AVG_READING_8_SCORE', y='AVG_MATH_8_SCORE', alpha=0.5)
plt.xlabel('8th Grade Reading Score')
plt.ylabel('8th Grade Math Score')
# Out:
# Text(0, 0.5, '8th Grade Math Score')

# %% [markdown]
# **This is a plot comparing the 8th graders' performance on the NAEP Reading Exam to the 8th graders' performance on the NAEP Math Exam. There seems to be a strong coorelation between these variables; when 8th greaders do better on the reading test, there is a steady increase in performance on the math test by the 8th graders. This makes logical sense as those who are prepared for one section would probably be prepared for the other section as well.**

# %%
df.plot.scatter(x='AVG_MATH_4_SCORE', y='AVG_MATH_8_SCORE', alpha=0.5)
plt.xlabel('4th Grade Math Score')
plt.ylabel('8th Grade Math Score')
# Out:
# Text(0, 0.5, '8th Grade Math Score')

# %%
# This plot compares the 4th graders' math scores and the 8th graders' math scores. It seems like if the 4th graders' did well on their
# math test, the 8th graders did also.

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['AVG_MATH_4_SCORE','AVG_READING_8_SCORE']].dropna()
y = df.loc[X.index]['AVG_MATH_8_SCORE']
y.fillna(y.median(), inplace=True)

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#      X, y, test_size=, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
# import your sklearn class here
from sklearn.linear_model import LinearRegression

# %%
# create your model here
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
# R^2 value
model.score(X_test, y_test)
# Out:
# 0.922144490269853

# %%
# Mean error
np.mean(model.predict(X_test)-y_test)
# Out:
# 0.577278130631992

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'AVG_MATH_4_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('8th Grade Math Score')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
col_name = 'AVG_READING_8_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "blue")
plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('8th Grade Math Score')
plt.title("Model Behavior on Testing Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior on Testing Set')

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# **<WRITE A PARAGRAPH SUMMARIZING YOUR WORK, FINDINGS, AND THE PERFORMANCE OF YOUR MODEL\>**
#
# Before developing the model, it was clear that there was a strong correlation between 4th grade math scores and 8th grade math scores and 8th grade reading scores and 8th math scores. The former makes sense because if 4th graders are on average doing well on the math test, 8th graders from the same year and state would also do well. Similarly, the latter makes sense because those who are prepared for one section would probably be prepared for the other section as well. This model worked very well on the training set, 4th grade math scores, and also very well on the testing set, 8th grade reading scores. The model had a very high R^2 value, meaning it was quite accurate. This was to be expected since both 4th grade math scores and 8th grade reading scores are strongly positively correlated with the response variable, 8th grade math scores.
